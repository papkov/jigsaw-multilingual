# %%
import numpy as np
import pandas as pd

# %%
from transformers import AutoTokenizer, XLMRobertaTokenizer, XLMRobertaConfig
tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-large')

# %%
embeddings = pd.read_csv('../ext/48chan_embeddings.txt', sep=' ', header=None, encoding='utf-8')
embeddings = embeddings.set_index(0)
embeddings.head()
# Out:
#                   1         2         3         4         5         6    \
# 0
# ftdna        0.111947  0.080415 -0.140500 -0.122228 -0.070147 -0.064512
# nunnery      0.035762 -0.178338 -0.084601  0.044585 -0.013513  0.001924
# gah          0.472260  0.223132 -0.490833  0.102011  0.115710 -0.007686
# sowell       2.177928  0.448875 -1.249432  2.219089  1.681310 -2.068980
# utnapishtim -0.074708  0.129301  0.066295 -0.065387  0.053657 -0.095528
#
#                   7         8         9         10   ...       141       142  \
# 0                                                    ...
# ftdna       -0.202917 -0.056402 -0.094567  0.052922  ... -0.045442  0.003004
# nunnery     -0.331925 -0.377152  0.054339  0.309774  ... -0.113540 -0.169089
# gah          0.215480 -0.760792  0.258075  0.505784  ...  0.616769  0.010519
# sowell       0.790133 -0.711840  1.153463 -1.051093  ...  1.099746  0.810128
# utnapishtim  0.013635 -0.092873  0.088119  0.045319  ... -0.026304  0.009382
#
# ...

# %%
embeddings
# Out:
#                   1         2         3         4         5         6    \
# 0
# ftdna        0.111947  0.080415 -0.140500 -0.122228 -0.070147 -0.064512
# nunnery      0.035762 -0.178338 -0.084601  0.044585 -0.013513  0.001924
# gah          0.472260  0.223132 -0.490833  0.102011  0.115710 -0.007686
# sowell       2.177928  0.448875 -1.249432  2.219089  1.681310 -2.068980
# utnapishtim -0.074708  0.129301  0.066295 -0.065387  0.053657 -0.095528
# ...               ...       ...       ...       ...       ...       ...
# cronys      -0.121869 -0.102006 -0.037965 -0.062614 -0.091945 -0.054312
# bunches      0.225634 -0.240904 -0.225752  0.279061  0.035547  0.049269
# cÃ©line     -0.009308  0.370282 -0.204251 -0.040939 -0.119868  0.115441
# >rick        0.069964  0.056009 -0.023301 -0.048173 -0.011222 -0.001887
# vand        -0.009129  0.057834 -0.027239 -0.034210  0.013124  0.109372
#
#                   7         8         9         10   ...       141       142  \
# ...

# %%
embeddings.index.tolist()
# Out:
# ['ftdna',
#  'nunnery',
#  'gah',
#  'sowell',
#  'utnapishtim',
#  'hitlerboos',
#  'bettynho',
#  'woods',
#  'clotted',
#  'spiders',
#  'paizo',
#  'fabianism',
#  'ultimatley',
#  'woody',
#  'trawling',
#  'comically',
#  'gae',
#  'regularize',
#  'caner',
#  'canes',
#  'eastasia',
#  'sprague',
#  'chatter',
#  '11/6/16',
#  'libertardians',
#  'facepalm.jpg',
#  'igual',
#  'mohammaden',
#  'caned',
#  'fundation',
#  '>trump',
#  '>starts',
#  'vann',
#  'canel',
#  'juucuck',
#  'accountâ\x84¢',
#  'sacced',
#  'Å\x9boy',
#  'slothful',
#  'naturopathic',
#  'd-d-degenerate',
#  "iq'ed",
#  'grenadiers',
#  'replacer',
#  'kÅ\x8dhai',
#  'replaces',
#  'bogyman',
#  'transvestism',
#  'comptuer',
#  'fullblooded',
#  'schizo-affective',
#  'bringing',
#  'jrpg',
#  'belongâ\x80¦',
#  'woo-wee',
#  'grueling',
#  '<natsoc',
#  'wooden',
#  'wholemeal',
#  'wednesday',
#  'vologda',
#  'chameleons',
#  'wooder',
#  'elgar',
#  'immunities',
#  'bbqs',
#  'briefwahl',
# ...

# %%
tokenizer.tokenize('nunnery')
# Out:
# ['▁nu', 'nner', 'y']
